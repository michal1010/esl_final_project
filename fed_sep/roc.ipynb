# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('metrics.csv')

# %%
df
# Out:
#                 race  num_examples       TPR       FPR  threshold
# 0              Other          2334  0.455592  0.190519        0.1
# 1          Caucasian           503  0.450549  0.158879        0.1
# 2   African-American           141  0.489796  0.184783        0.1
# 3           Hispanic           924  0.449173  0.183633        0.1
# 4              Asian          1537  0.450000  0.187948        0.1
# 5    Native American           210  0.480519  0.180451        0.1
# 6              Other          2334  0.455592  0.190519        0.2
# 7          Caucasian           503  0.450549  0.158879        0.2
# 8   African-American           141  0.489796  0.184783        0.2
# 9           Hispanic           924  0.449173  0.183633        0.2
# 10             Asian          1537  0.450000  0.187948        0.2
# 11   Native American           210  0.480519  0.180451        0.2
# 12             Other          2334  0.455592  0.190519        0.3
# 13         Caucasian           503  0.450549  0.158879        0.3
# 14  African-American           141  0.489796  0.184783        0.3
# 15          Hispanic           924  0.449173  0.183633        0.3
# 16             Asian          1537  0.450000  0.187948        0.3
# 17   Native American           210  0.480519  0.180451        0.3
# 18             Other          2334  0.455592  0.190519        0.4
# 19         Caucasian           503  0.450549  0.158879        0.4
# 20  African-American           141  0.489796  0.184783        0.4
# 21          Hispanic           924  0.449173  0.183633        0.4
# 22             Asian          1537  0.450000  0.187948        0.4
# 23   Native American           210  0.480519  0.180451        0.4
# 24             Other          2334  0.455592  0.190519        0.5
# 25         Caucasian           503  0.450549  0.158879        0.5
# 26  African-American           141  0.489796  0.184783        0.5
# 27          Hispanic           924  0.449173  0.183633        0.5
# 28             Asian          1537  0.450000  0.187948        0.5
# 29   Native American           210  0.480519  0.180451        0.5
# 30             Other          2334  0.455592  0.190519        0.6
# 31         Caucasian           503  0.450549  0.158879        0.6
# 32  African-American           141  0.489796  0.184783        0.6
# 33          Hispanic           924  0.449173  0.183633        0.6
# 34             Asian          1537  0.450000  0.187948        0.6
# 35   Native American           210  0.480519  0.180451        0.6
# 36             Other          2334  0.455592  0.190519        0.7
# 37         Caucasian           503  0.450549  0.158879        0.7
# 38  African-American           141  0.489796  0.184783        0.7
# 39          Hispanic           924  0.449173  0.183633        0.7
# 40             Asian          1537  0.450000  0.187948        0.7
# 41   Native American           210  0.480519  0.180451        0.7
# 42             Other          2334  0.455592  0.190519        0.8
# 43         Caucasian           503  0.450549  0.158879        0.8
# 44  African-American           141  0.489796  0.184783        0.8
# 45          Hispanic           924  0.449173  0.183633        0.8
# 46             Asian          1537  0.450000  0.187948        0.8
# 47   Native American           210  0.480519  0.180451        0.8
# 48             Other          2334  0.455592  0.190519        0.9
# 49         Caucasian           503  0.450549  0.158879        0.9
# 50  African-American           141  0.489796  0.184783        0.9
# 51          Hispanic           924  0.449173  0.183633        0.9
# 52             Asian          1537  0.450000  0.187948        0.9
# 53   Native American           210  0.480519  0.180451        0.9

# %%
df.loc[df['race'] == 'Hispanic']['TPR'].values
# Out:
# array([0.44917258, 0.44917258, 0.44917258, 0.44917258, 0.44917258,
#        0.44917258, 0.44917258, 0.44917258, 0.44917258])

# %%
plt.plot(
    df.loc[df['race'] == 'Hispanic']['FPR'].values,
    df.loc[df['race'] == 'Hispanic']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Asian']['FPR'].values,
    df.loc[df['race'] == 'Asian']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Caucasian']['FPR'].values,
    df.loc[df['race'] == 'Caucasian']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Other']['FPR'].values,
    df.loc[df['race'] == 'Other']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'African-American']['FPR'].values,
    df.loc[df['race'] == 'African-American']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Native American']['FPR'].values,
    df.loc[df['race'] == 'Native American']['TPR'].values,
)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC')
plt.legend(['Hispanic', 'Asian', 'Caucasian', 'Other', 'African-American', 'Native American'])
