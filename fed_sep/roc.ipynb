# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('metrics.csv')

# %%
df.drop(columns=["num_examples"])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.drop("num_examples")
#       2 df
#
# File c:\fl\venv\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File c:\fl\venv\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File c:\fl\venv\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File c:\fl\venv\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['num_examples'] not found in axis"

# %%
df.loc[df['race'] == 'Hispanic']['TPR'].values
# Out:
# array([1.        , 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969, 0.60727969, 0.60727969, 0.60727969, 0.60727969,
#        0.60727969])

# %%
plt.plot(
    df.loc[df['race'] == 'Hispanic']['FPR'].values,
    df.loc[df['race'] == 'Hispanic']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Asian']['FPR'].values,
    df.loc[df['race'] == 'Asian']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Caucasian']['FPR'].values,
    df.loc[df['race'] == 'Caucasian']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Other']['FPR'].values,
    df.loc[df['race'] == 'Other']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'African-American']['FPR'].values,
    df.loc[df['race'] == 'African-American']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Native American']['FPR'].values,
    df.loc[df['race'] == 'Native American']['TPR'].values,
)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC')
plt.legend(['Hispanic', 'Asian', 'Caucasian', 'Other', 'African-American', 'Native American'])
