# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('metrics.csv')

# %%
df
# Out:
#                 race  num_examples       TPR       FPR  threshold
# 0              Other           174  1.000000  1.000000        0.1
# 1          Caucasian          1186  1.000000  1.000000        0.1
# 2   African-American          1873  1.000000  1.000000        0.1
# 3           Hispanic           262  1.000000  1.000000        0.1
# 4              Asian             7  1.000000  0.800000        0.1
# 5    Native American            13  1.000000  1.000000        0.1
# 6              Other           174  0.983607  0.823009        0.2
# 7          Caucasian          1186  0.980843  0.887048        0.2
# 8   African-American          1873  0.990458  0.969697        0.2
# 9           Hispanic           262  0.923077  0.812865        0.2
# 10             Asian             7  1.000000  0.800000        0.2
# 11   Native American            13  1.000000  0.857143        0.2
# 12             Other           174  0.934426  0.592920        0.3
# 13         Caucasian          1186  0.904215  0.674699        0.3
# 14  African-American          1873  0.961832  0.849697        0.3
# 15          Hispanic           262  0.780220  0.514620        0.3
# 16             Asian             7  1.000000  0.400000        0.3
# 17   Native American            13  1.000000  0.571429        0.3
# 18             Other           174  0.721311  0.345133        0.4
# 19         Caucasian          1186  0.724138  0.411145        0.4
# 20  African-American          1873  0.883588  0.678788        0.4
# 21          Hispanic           262  0.549451  0.239766        0.4
# 22             Asian             7  0.500000  0.000000        0.4
# 23   Native American            13  1.000000  0.285714        0.4
# 24             Other           174  0.377049  0.150442        0.5
# 25         Caucasian          1186  0.486590  0.209337        0.5
# 26  African-American          1873  0.721374  0.444848        0.5
# 27          Hispanic           262  0.318681  0.105263        0.5
# 28             Asian             7  0.500000  0.000000        0.5
# 29   Native American            13  0.500000  0.000000        0.5
# 30             Other           174  0.213115  0.026549        0.6
# 31         Caucasian          1186  0.245211  0.072289        0.6
# 32  African-American          1873  0.500000  0.235152        0.6
# 33          Hispanic           262  0.164835  0.052632        0.6
# 34             Asian             7  0.000000  0.000000        0.6
# 35   Native American            13  0.500000  0.000000        0.6
# 36             Other           174  0.081967  0.008850        0.7
# 37         Caucasian          1186  0.111111  0.034639        0.7
# 38  African-American          1873  0.272901  0.109091        0.7
# 39          Hispanic           262  0.054945  0.017544        0.7
# 40             Asian             7  0.000000  0.000000        0.7
# 41   Native American            13  0.166667  0.000000        0.7
# 42             Other           174  0.049180  0.000000        0.8
# 43         Caucasian          1186  0.022989  0.013554        0.8
# 44  African-American          1873  0.110687  0.037576        0.8
# 45          Hispanic           262  0.010989  0.005848        0.8
# 46             Asian             7  0.000000  0.000000        0.8
# 47   Native American            13  0.166667  0.000000        0.8
# 48             Other           174  0.016393  0.000000        0.9
# 49         Caucasian          1186  0.003831  0.004518        0.9
# 50  African-American          1873  0.012405  0.004848        0.9
# 51          Hispanic           262  0.000000  0.000000        0.9
# 52             Asian             7  0.000000  0.000000        0.9
# 53   Native American            13  0.000000  0.000000        0.9

# %%
df.loc[df['race'] == 'Hispanic']['TPR'].values
# Out:
# array([1.        , 0.92307692, 0.78021978, 0.54945055, 0.31868132,
#        0.16483516, 0.05494505, 0.01098901, 0.        ])

# %%
plt.plot(
    df.loc[df['race'] == 'Hispanic']['FPR'].values,
    df.loc[df['race'] == 'Hispanic']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Asian']['FPR'].values,
    df.loc[df['race'] == 'Asian']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Caucasian']['FPR'].values,
    df.loc[df['race'] == 'Caucasian']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Other']['FPR'].values,
    df.loc[df['race'] == 'Other']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'African-American']['FPR'].values,
    df.loc[df['race'] == 'African-American']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Native American']['FPR'].values,
    df.loc[df['race'] == 'Native American']['TPR'].values,
)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC')
plt.legend(['Hispanic', 'Asian', 'Caucasian', 'Other', 'African-American', 'Native American'])
