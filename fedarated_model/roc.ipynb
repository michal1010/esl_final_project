# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('metrics.csv')

# %%
df
# Out:
#                 race  num_examples       TPR       FPR  threshold
# 0              Other           141  1.000000  1.000000        0.1
# 1          Caucasian           924  1.000000  1.000000        0.1
# 2   African-American          1537  1.000000  1.000000        0.1
# 3           Hispanic           210  1.000000  1.000000        0.1
# 4              Asian            15  1.000000  1.000000        0.1
# 5    Native American            10  1.000000  1.000000        0.1
# 6              Other           141  1.000000  1.000000        0.2
# 7          Caucasian           924  1.000000  1.000000        0.2
# 8   African-American          1537  1.000000  1.000000        0.2
# 9           Hispanic           210  1.000000  1.000000        0.2
# 10             Asian            15  1.000000  1.000000        0.2
# 11   Native American            10  1.000000  1.000000        0.2
# 12             Other           141  1.000000  0.989130        0.3
# 13         Caucasian           924  1.000000  0.996008        0.3
# 14  African-American          1537  0.998810  1.000000        0.3
# 15          Hispanic           210  1.000000  1.000000        0.3
# 16             Asian            15  1.000000  1.000000        0.3
# 17   Native American            10  1.000000  1.000000        0.3
# 18             Other           141  0.979592  0.826087        0.4
# 19         Caucasian           924  0.895981  0.732535        0.4
# 20  African-American          1537  0.970238  0.909613        0.4
# 21          Hispanic           210  0.922078  0.812030        0.4
# 22             Asian            15  0.666667  0.583333        0.4
# 23   Native American            10  1.000000  0.750000        0.4
# 24             Other           141  0.265306  0.043478        0.5
# 25         Caucasian           924  0.312057  0.091816        0.5
# 26  African-American          1537  0.527381  0.246772        0.5
# 27          Hispanic           210  0.259740  0.097744        0.5
# 28             Asian            15  0.333333  0.000000        0.5
# 29   Native American            10  1.000000  0.000000        0.5
# 30             Other           141  0.020408  0.000000        0.6
# 31         Caucasian           924  0.018913  0.007984        0.6
# 32  African-American          1537  0.072619  0.024390        0.6
# 33          Hispanic           210  0.025974  0.007519        0.6
# 34             Asian            15  0.000000  0.000000        0.6
# 35   Native American            10  0.500000  0.000000        0.6
# 36             Other           141  0.000000  0.000000        0.7
# 37         Caucasian           924  0.000000  0.000000        0.7
# 38  African-American          1537  0.005952  0.002869        0.7
# 39          Hispanic           210  0.000000  0.000000        0.7
# 40             Asian            15  0.000000  0.000000        0.7
# 41   Native American            10  0.000000  0.000000        0.7
# 42             Other           141  0.000000  0.000000        0.8
# 43         Caucasian           924  0.000000  0.000000        0.8
# 44  African-American          1537  0.000000  0.000000        0.8
# 45          Hispanic           210  0.000000  0.000000        0.8
# 46             Asian            15  0.000000  0.000000        0.8
# 47   Native American            10  0.000000  0.000000        0.8
# 48             Other           141  0.000000  0.000000        0.9
# 49         Caucasian           924  0.000000  0.000000        0.9
# 50  African-American          1537  0.000000  0.000000        0.9
# 51          Hispanic           210  0.000000  0.000000        0.9
# 52             Asian            15  0.000000  0.000000        0.9
# 53   Native American            10  0.000000  0.000000        0.9

# %%
df.loc[df['race'] == 'Hispanic']['TPR'].values
# Out:
# array([1.        , 1.        , 1.        , 0.92207792, 0.25974026,
#        0.02597403, 0.        , 0.        , 0.        ])

# %%
plt.plot(
    df.loc[df['race'] == 'Hispanic']['FPR'].values,
    df.loc[df['race'] == 'Hispanic']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Asian']['FPR'].values,
    df.loc[df['race'] == 'Asian']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Caucasian']['FPR'].values,
    df.loc[df['race'] == 'Caucasian']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Other']['FPR'].values,
    df.loc[df['race'] == 'Other']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'African-American']['FPR'].values,
    df.loc[df['race'] == 'African-American']['TPR'].values,
)

plt.plot(
    df.loc[df['race'] == 'Native American']['FPR'].values,
    df.loc[df['race'] == 'Native American']['TPR'].values,
)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC')
plt.legend(['Hispanic', 'Asian', 'Caucasian', 'Other', 'African-American', 'Native American'])
